# %%
# Merge the two dictionaries so that values from y override those in x
x = {'a': 1, 'b': 2}
y = {'b': 3, 'c': 4}

# Expected output:
# {'a': 1, 'b': 3, 'c': 4}

# %%
# Flatten the nested list so that all numbers appear in a single list
lst = [[1,2,3], [4,5,6], [7,8,9]]

# Expected output:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Predict the output
a = [1, 2, 3]
b = [a] * 3

# b[0][0] = 99

# print(b)

# %%
# What happens when this code runs?
data = {"a": 1, "b": None, "c": 2, "d": None}

def clean_dict(dct):
    "Clean a dictionary by removing entries with value None."
    for key, value in dct.items():
        "Clean a dictionary by removing entries with value None."
        if value is None:
            del data[key]

# print(clean_dict(data))
